# %%
print("hi")
# Out:
# hi

# %% [markdown]
# Univariate Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Visadataset.csv')

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# Set style
sns.set_style('whitegrid')

# %% [markdown]
# 1) HISTOGRAMS

# %%
# Histogram of prevailing wage
plt.figure(figsize=(10, 6))
sns.histplot(df['prevailing_wage'], bins=50, kde=True)
plt.title('Distribution of Prevailing Wage')
plt.xlabel('Prevailing Wage')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of year of establishment
plt.figure(figsize=(10, 6))
sns.histplot(df['yr_of_estab'], bins=50)
plt.title('Distribution of Year of Establishment')
plt.xlabel('Year of Establishment')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2)  Bar Plots / Count Plots

# %%
# Bar plot for education levels
plt.figure(figsize=(10, 6))
sns.countplot(y='education_of_employee', data=df, order=df['education_of_employee'].value_counts().index)
plt.title('Count of Applications by Education Level')
plt.xlabel('Count')
plt.ylabel('Education Level')
plt.show()

# %%
# Bar plot for continents
plt.figure(figsize=(10, 6))
sns.countplot(y='continent', data=df, order=df['continent'].value_counts().index)
plt.title('Count of Applications by Continent')
plt.xlabel('Count')
plt.ylabel('Continent')
plt.show()

# %%
# Bar plot for case status
plt.figure(figsize=(8, 5))
sns.countplot(x='case_status', data=df)
plt.title('Count of Certified vs Denied Cases')
plt.xlabel('Case Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 3) Pie Charts

# %%
# Pie chart for full time position
plt.figure(figsize=(8, 8))
df['full_time_position'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Full Time vs Part Time Positions')
plt.ylabel('')
plt.show()

# %%
# Pie chart for job training requirement
plt.figure(figsize=(8, 8))
df['requires_job_training'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Proportion Requiring Job Training')
plt.ylabel('')
plt.show()

# %% [markdown]
# 4)  KDE Plots

# %%
# KDE plot for prevailing wage
plt.figure(figsize=(10, 6))
sns.kdeplot(df['prevailing_wage'], shade=True)
plt.title('Density of Prevailing Wage')
plt.xlabel('Prevailing Wage')
plt.show()
# Out:
# d:\projects\visaapproval\venv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# KDE plot by case status
plt.figure(figsize=(10, 6))
sns.kdeplot(df[df['case_status']=='Certified']['prevailing_wage'], label='Certified', shade=True)
sns.kdeplot(df[df['case_status']=='Denied']['prevailing_wage'], label='Denied', shade=True)
plt.title('Density of Prevailing Wage by Case Status')
plt.xlabel('Prevailing Wage')
plt.legend()
plt.show()
# Out:
# d:\projects\visaapproval\venv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# d:\projects\visaapproval\venv\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   after removing the cwd from sys.path.

# %% [markdown]
# 5) Box Plots

# %%
# Box plot of wages by education level
plt.figure(figsize=(12, 6))
sns.boxplot(x='education_of_employee', y='prevailing_wage', data=df)
plt.title('Prevailing Wage Distribution by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Prevailing Wage')
plt.xticks(rotation=45)
plt.show()

# %%
# Box plot of wages by case status
plt.figure(figsize=(8, 6))
sns.boxplot(x='case_status', y='prevailing_wage', data=df)
plt.title('Prevailing Wage Distribution by Case Status')
plt.xlabel('Case Status')
plt.ylabel('Prevailing Wage')
plt.show()

# %% [markdown]
# 6) Strip Plots

# %%
# Strip plot of wages by case status
plt.figure(figsize=(10, 6))
sns.stripplot(x='case_status', y='prevailing_wage', data=df, jitter=True, alpha=0.5)
plt.title('Prevailing Wage by Case Status (Strip Plot)')
plt.xlabel('Case Status')
plt.ylabel('Prevailing Wage')
plt.show()

# %%
#Wage Distribution by Education Level 
plt.figure(figsize=(12, 6))
sns.stripplot(
    x='education_of_employee', 
    y='prevailing_wage', 
    data=df.sample(200),  # Sample to avoid overplotting
    jitter=True, 
    alpha=0.7,
    palette='viridis'
)
plt.title('Prevailing Wage by Education Level (Strip Plot)', fontsize=14)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Prevailing Wage ($)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# d:\projects\visaapproval\venv\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   if __name__ == "__main__":

# %%
#Wage Distribution by Full-Time vs. Part-Time Positions
plt.figure(figsize=(10, 6))
sns.stripplot(
    x='full_time_position', 
    y='prevailing_wage', 
    data=df.sample(200), 
    jitter=True, 
    alpha=0.6,
    palette={'Y': 'blue', 'N': 'orange'}
)
plt.title('Wage Distribution by Full-Time vs. Part-Time (Strip Plot)', fontsize=14)
plt.xlabel('Full-Time Position (Y/N)', fontsize=12)
plt.ylabel('Prevailing Wage ($)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# d:\projects\visaapproval\venv\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   if __name__ == "__main__":

# %% [markdown]
# 7)  Violin Plots

# %%
# Wage Distribution by Case Status
plt.figure(figsize=(10, 6))
sns.violinplot(
    x='case_status', 
    y='prevailing_wage', 
    data=df,
    palette={'Certified': 'lightgreen', 'Denied': 'salmon'},
    inner='quartile'  # Shows median and quartiles
)
plt.title('Wage Distribution by Case Status (Violin Plot)', fontsize=14)
plt.xlabel('Case Status', fontsize=12)
plt.ylabel('Prevailing Wage ($)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
