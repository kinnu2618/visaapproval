# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
file_path = "Visadataset_cleaned.csv"  # Update if needed
df = pd.read_csv(file_path)

# %%
#Identify categorical columns
categorical_cols = df.select_dtypes(include='object').columns

# %%
#Apply Label Encoding to each categorical column
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Save encoder if needed later

# %%
df
# Out:
#        continent  education of employee  has job experience  \
# 0              1                      2                   0
# 1              1                      3                   1
# 2              1                      0                   0
# 3              1                      0                   0
# 4              0                      3                   1
# ...          ...                    ...                 ...
# 25048          0                      1                   0
# 25049          1                      0                   1
# 25050          1                      3                   1
# 25051          1                      3                   1
# 25052          1                      0                   1
#
#        requires job training  no of employees  yr of estab  \
# 0                          0            14513         2007
# 1                          0             2412         2002
# 2                          1            44444         2008
# 3                          0               98         1897
# 4                          0             1082         2005
# ...                      ...              ...          ...
# 25048                      0             2594         1979
# 25049                      1             2601         2008
# 25050                      0             1121         1910
# 25051                      1             1918         1887
# 25052                      0             3195         1960
#
#        region of employment  prevailing wage  unit of wage  \
# 0                         4         592.2029             0
# 1                         2       83425.6500             3
# 2                         4      122996.8600             3
# 3                         4       83434.0300             3
# 4                         3      149907.3900             3
# ...                     ...              ...           ...
# 25048                     2       51104.7800             3
# 25049                     3       77092.5700             3
# 25050                     3      146298.8500             3
# 25051                     4       86154.7700             3
# 25052                     1       70876.9100             3
#
#        full time position  case status
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            1
# 4                       1            0
# ...                   ...          ...
# 25048                   1            0
# 25049                   1            0
# 25050                   0            0
# 25051                   1            0
# 25052                   1            0
#
# [25053 rows x 11 columns]

# %%
#Save the fully numeric dataset
df.to_csv("Visadataset_numerical.csv", index=False)

# %%
# Show label encoding mapping for each column
for col, le in label_encoders.items():
    print(f"\nLabel encoding for column '{col}':")
    for original, encoded in zip(le.classes_, le.transform(le.classes_)):
        print(f"  {original} → {encoded}")
# Out:
# Label encoding for column 'continent':
#   Africa → 0
#   Asia → 1
#   Europe → 2
#   North America → 3
#   Oceania → 4
#   South America → 5
#
# Label encoding for column 'education of employee':
#   Bachelor's → 0
#   Doctorate → 1
#   High School → 2
#   Master's → 3
#
# Label encoding for column 'has job experience':
#   No → 0
#   Yes → 1
#
# Label encoding for column 'requires job training':
#   No → 0
#   Yes → 1
#
# Label encoding for column 'region of employment':
#   Island → 0
#   Midwest → 1
#   Northeast → 2
#   South → 3
#   West → 4
#
# Label encoding for column 'unit of wage':
#   Hour → 0
#   Month → 1
#   Week → 2
#   Year → 3
#
# Label encoding for column 'full time position':
#   No → 0
#   Yes → 1
#
# Label encoding for column 'case status':
#   Certified → 0
#   Denied → 1
