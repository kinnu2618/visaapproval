# %%
import pandas as pd

# %%
# Step 1: Load the dataset
file_path = "Visadataset.csv"  
df = pd.read_csv(file_path)

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
clean_df = df.copy()

# %%
binary_cols = ['has_job_experience', 'requires_job_training', 'full_time_position']
clean_df[binary_cols] = clean_df[binary_cols].replace({'Y': 'Yes', 'N': 'No'})

# %%
clean_df.columns = [col.lower().replace('_', ' ') for col in clean_df.columns]

# %%
clean_df
# Out:
#          case id continent education of employee has job experience  \
# 0         EZYV01      Asia           High School                 No
# 1         EZYV02      Asia              Master's                Yes
# 2         EZYV03      Asia            Bachelor's                 No
# 3         EZYV04      Asia            Bachelor's                 No
# 4         EZYV05    Africa              Master's                Yes
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                Yes
# 25476  EZYV25477      Asia           High School                Yes
# 25477  EZYV25478      Asia              Master's                Yes
# 25478  EZYV25479      Asia              Master's                Yes
# 25479  EZYV25480      Asia            Bachelor's                Yes
#
#       requires job training  no of employees  yr of estab  \
# 0                        No            14513         2007
# 1                        No             2412         2002
# 2                       Yes            44444         2008
# 3                        No               98         1897
# 4                        No             1082         2005
# ...                     ...              ...          ...
# 25475                   Yes             2601         2008
# 25476                    No             3274         2006
# 25477                    No             1121         1910
# 25478                   Yes             1918         1887
# 25479                    No             3195         1960
#
#       region of employment  prevailing wage unit of wage full time position  \
# 0                     West         592.2029         Hour                Yes
# 1                Northeast       83425.6500         Year                Yes
# 2                     West      122996.8600         Year                Yes
# 3                     West       83434.0300         Year                Yes
# 4                    South      149907.3900         Year                Yes
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                Yes
# 25476            Northeast      279174.7900         Year                Yes
# 25477                South      146298.8500         Year                 No
# 25478                 West       86154.7700         Year                Yes
# 25479              Midwest       70876.9100         Year                Yes
#
#       case status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
if 'case id' in clean_df.columns:
    clean_df.drop(columns=['case id'], inplace=True)

# %%
clean_df
# Out:
#       continent education of employee has job experience  \
# 0          Asia           High School                 No
# 1          Asia              Master's                Yes
# 2          Asia            Bachelor's                 No
# 3          Asia            Bachelor's                 No
# 4        Africa              Master's                Yes
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                Yes
# 25476      Asia           High School                Yes
# 25477      Asia              Master's                Yes
# 25478      Asia              Master's                Yes
# 25479      Asia            Bachelor's                Yes
#
#       requires job training  no of employees  yr of estab  \
# 0                        No            14513         2007
# 1                        No             2412         2002
# 2                       Yes            44444         2008
# 3                        No               98         1897
# 4                        No             1082         2005
# ...                     ...              ...          ...
# 25475                   Yes             2601         2008
# 25476                    No             3274         2006
# 25477                    No             1121         1910
# 25478                   Yes             1918         1887
# 25479                    No             3195         1960
#
#       region of employment  prevailing wage unit of wage full time position  \
# 0                     West         592.2029         Hour                Yes
# 1                Northeast       83425.6500         Year                Yes
# 2                     West      122996.8600         Year                Yes
# 3                     West       83434.0300         Year                Yes
# 4                    South      149907.3900         Year                Yes
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                Yes
# 25476            Northeast      279174.7900         Year                Yes
# 25477                South      146298.8500         Year                 No
# 25478                 West       86154.7700         Year                Yes
# 25479              Midwest       70876.9100         Year                Yes
#
#       case status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 11 columns]

# %%
#Handle outliers in 'prevailing wage' using the IQR method
q1 = clean_df['prevailing wage'].quantile(0.25)
q3 = clean_df['prevailing wage'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Filter out outliers
clean_df = clean_df[
    (clean_df['prevailing wage'] >= lower_bound) &
    (clean_df['prevailing wage'] <= upper_bound)
]

# %%
clean_df.to_csv("Visadataset_cleaned.csv", index=False)

# %%
clean_df
# Out:
#       continent education of employee has job experience  \
# 0          Asia           High School                 No
# 1          Asia              Master's                Yes
# 2          Asia            Bachelor's                 No
# 3          Asia            Bachelor's                 No
# 4        Africa              Master's                Yes
# ...         ...                   ...                ...
# 25474    Africa             Doctorate                 No
# 25475      Asia            Bachelor's                Yes
# 25477      Asia              Master's                Yes
# 25478      Asia              Master's                Yes
# 25479      Asia            Bachelor's                Yes
#
#       requires job training  no of employees  yr of estab  \
# 0                        No            14513         2007
# 1                        No             2412         2002
# 2                       Yes            44444         2008
# 3                        No               98         1897
# 4                        No             1082         2005
# ...                     ...              ...          ...
# 25474                    No             2594         1979
# 25475                   Yes             2601         2008
# 25477                    No             1121         1910
# 25478                   Yes             1918         1887
# 25479                    No             3195         1960
#
#       region of employment  prevailing wage unit of wage full time position  \
# 0                     West         592.2029         Hour                Yes
# 1                Northeast       83425.6500         Year                Yes
# 2                     West      122996.8600         Year                Yes
# 3                     West       83434.0300         Year                Yes
# 4                    South      149907.3900         Year                Yes
# ...                    ...              ...          ...                ...
# 25474            Northeast       51104.7800         Year                Yes
# 25475                South       77092.5700         Year                Yes
# 25477                South      146298.8500         Year                 No
# 25478                 West       86154.7700         Year                Yes
# 25479              Midwest       70876.9100         Year                Yes
#
#       case status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25474   Certified
# 25475   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25053 rows x 11 columns]

# %%
clean_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
clean_df['education of employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
clean_df['region of employment'].unique()
# Out:
# array(['West', 'Northeast', 'South', 'Midwest', 'Island'], dtype=object)

# %%
clean_df['unit of wage'].unique()
# Out:
# array(['Hour', 'Year', 'Week', 'Month'], dtype=object)
